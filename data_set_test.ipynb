# %%
from glob import glob
import numpy as np

# %% [markdown]
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_000.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_001.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_002.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_003.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_004.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_005.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_006.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_007.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_008.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_009.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_010.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_011.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_012.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_013.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_014.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_015.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_016.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_017.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_018.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_019.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_020.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_021.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_022.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_023.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_024.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_025.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_026.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_027.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_028.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_029.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_030.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_031.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_032.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_033.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_034.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_036.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_037.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_038.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_039.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_040.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_041.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_042.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_043.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_044.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_045.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_046.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_047.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_048.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_049.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_050.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_051.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_052.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_053.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_054.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_055.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_056.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_057.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_058.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_059.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_060.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_061.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_062.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_063.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_064.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_065.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_066.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_067.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_068.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_069.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_070.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_071.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_072.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_073.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_074.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_075.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_076.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_077.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_078.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_079.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_080.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_081.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_082.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_083.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_084.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_085.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_086.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_087.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_088.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_089.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_090.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_091.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_092.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_093.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_094.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_095.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_096.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_097.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_098.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_099.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_100.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_101.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_102.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_103.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_104.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_105.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_106.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_107.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_108.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_109.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_110.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_111.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_112.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_113.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_114.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_115.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_116.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_117.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_118.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_119.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_120.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_121.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_122.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_123.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_124.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_125.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_126.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_127.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_128.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_129.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_130.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_131.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_132.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_133.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_134.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_135.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_136.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_137.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_138.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_139.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_140.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_141.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_142.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_143.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_144.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_145.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_146.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_147.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_148.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_149.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_150.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_151.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_152.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_153.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_154.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_155.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_156.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_157.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_158.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_159.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_160.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_161.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_162.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_163.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_164.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_165.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_166.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_167.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_168.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_169.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_170.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_171.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_172.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_173.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_174.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_175.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_176.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_177.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_178.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_179.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_180.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_181.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_182.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_183.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_184.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_185.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_186.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_187.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_188.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_189.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_190.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_191.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_194.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_197.npy
# all_data_building/T_316000_233500_NE_T_316000_233500_SW/building_198.npy

# %%
test = np.loadtxt("test.txt")

# %%
buff.min(axis=0)[2]

# %%
test.min(axis=0)[2]

# %%
buff[2][2]

# %%
data_building = np.loadtxt("data_building.txt")
data_bulding_sub_building = np.loadtxt("data_bulding_sub_building.txt")
data_building_index = np.where(data_building[:,0]>318000)
data_bulding_sub_building_index = np.where(data_bulding_sub_building[:,0]>318000)
data_building = data_building[np.where(data_building[:,0]<318000)]
buff  = data_building[data_building_index]
buff = np.append(buff,data_bulding_sub_building,axis=0)
buff[:,0] = buff[:,0]-2000
buff[:,1] = buff[:,1]-3619
buff[:,2] = buff[:,2]+27
np.savetxt("shifted_data_building.txt",data_building,fmt="%1.9f %1.9f %1.9f %d %d %d" )
np.savetxt("shifted_data_bulding_sub_building.txt",buff,fmt="%1.9f %1.9f %1.9f %d %d %d")
